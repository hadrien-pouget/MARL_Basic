# %% [markdown]
# Conclusions:
# - This mostly looks like what you'd expect
# - In the part where I explore strategies, the strategies are stochastic. However, if they do something (e.g. action A) with probability > 0.95, I show them as "A". If they do nothing with probability > 0.95, then I put them in 'None'. This was never the case.
# - Something in the last figure seems off. Having checked, that low AB point doesn't exist, so I probably have a small error in the plotting code

# %%
from utils import plot_from_folder, plot_oneshot_policies, plot_res_with_pol1
import matplotlib.pyplot as plt
noise_mag = 0

# %% [markdown]
# # Game from Distribution vs Information

# %% [markdown]
# First, we look at p=0. That is, it's BoS (there is no chance that they're in a both-prefer game)

# %%
plot_from_folder("DistInf_bos_naive_oneshot", noise_mag=noise_mag)
plt.show()
plot_from_folder("DistInf_bos_lola_oneshot", noise_mag=noise_mag)

# %% [markdown]
# Now, we look at p=1 and a=2. They always both prefer something, but can get stuck in local equilibria. The optimal answer is AB, and they should always play the same move.

# %%
plot_from_folder("DistInf_coop_naive_oneshot", noise_mag=noise_mag)
plt.show()
plot_from_folder("DistInf_coop_lola_oneshot", noise_mag=noise_mag)

# %%
plot_oneshot_policies("DistInf_coop_naive_oneshot")
plt.show()
plot_oneshot_policies("DistInf_coop_lola_oneshot")

# %%
plot_res_with_pol1("DistInf_coop_naive_oneshot", noise_mag=noise_mag)
